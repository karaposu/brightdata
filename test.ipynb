# %%
from brightdata import scrape_url
import nest_asyncio

# %%
# pip install nest_asyncio
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
nest_asyncio.apply()
url="https://www.1337x.to/home/"
scrape_result=scrape_url(url, fallback_to_browser_api=True)

# %%
scrape_result
# Out:
# ScrapeResult(success=True, url='https://www.1337x.to/home/', status='ready', data='<!DOCTYPE html><html><head>\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<title>Download verified torrents: movies, music, games, software | 1337x</title>\n<meta name="description" content="1337x is a search engine to find your favorite torrents.">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n\n<link rel="stylesheet" href="/css/jquery-ui.css">\n<link rel="stylesheet" href="/css/slick.css">\n<link rel="stylesheet" href="/css/icons.css">\n<link rel="stylesheet" href="/css/style10.2025-08-05-09.css">\n\n<link rel="shortcut icon" href="/favicon.ico">\n<!--[if lt IE 9]><script src = "/js/html5shiv.js"></script><![endif]-->\n\n\n<script type="text/javascript" id="antiClickjackJS">\nif (self === top) {\nvar antiClickjack = document.getElementById("antiClickjack");\nantiClickjack.parentNode.removeChild(antiClickjack);\n} else {\ntop.location = self.l
# ...

# %%
import json

def pretty_print_scrape_result(result):
      for key, value in result.__dict__.items():
          if key == 'data' and value:
              print(f"{key}: {value[:200]}...")
          elif isinstance(value, (list, dict)):
              print(f"{key}: {json.dumps(value, indent=2)}")
          else:
              print(f"{key}: {value}")

# %%
pretty_print_scrape_result(scrape_result)
# Out:
# success: True
# url: https://www.1337x.to/home/
# status: ready
# data: <!DOCTYPE html><html><head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <title>Download verified torrents: movies, music, games, software | 1337x</title>
# <meta name="d...
# error: None
# snapshot_id: None
# cost: 0.0007732048630714417
# fallback_used: False
# root_domain: 1337x
# request_sent_at: 2025-08-05 07:59:04.905039
# snapshot_id_received_at: None
# snapshot_polled_at: []
# data_received_at: 2025-08-05 07:59:18.924538
# event_loop_id: 4357051600
# browser_warmed_at: None
# html_char_size: 98828
# row_count: None
# field_count: None
